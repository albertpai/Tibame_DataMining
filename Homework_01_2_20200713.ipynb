# %% [markdown]
# <a href="https://colab.research.google.com/github/albertpai/Tibame_DataMining/blob/master/Homework_01_2_20200713.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##解析PTT信用卡版面，分頁（未成功）

# %%
import requests
headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/83.0.4103.116 Safari/537.36'
}
#res = requests.get('https://www.ptt.cc/bbs/creditcard/index.html', headers = headers)

from bs4 import BeautifulSoup
soup = BeautifulSoup(res.text, 'lxml')

domain = 'https://www.ptt.cc/'
creditcard = []

for i in range(3327, 3325, -1):
  pageurl = 'https://www.ptt.cc/bbs/creditcard/index{}.html'.format(i)
  res = requests.get(pageurl, headers=headers)
  for tr in soup.select('.r-ent'):
    if tr.select_one('.title a'):
      row = {}
      row['Title'] = tr.select_one('.title a').text
      row['Link'] = domain + tr.select_one('.title a').get('href')
      row['Date'] = tr.select_one('.date').text
      row['Author'] = tr.select_one('.author').text
      creditcard.append(row)
      #print(tr.select_one('.title a').text)
      #print(domain + tr.select_one('.title a').get('href'))
      #print(tr.select_one('.date').text)
      #print(tr.select_one('.author').text)
      #print('=========================================')

import pandas
creditcard_df = pandas.DataFrame(creditcard)
creditcard_df
# Out:
#                                     Title  ...       Author
# 0                       [心得] 渣打現金回饋御璽卡 核卡  ...    bugerbite
# 1                       [問題] 永豐幣倍卡實際刷卡金額？  ...  sunsky13579
# 2                      [心得] 渣打現金回饋御璽卡  核卡  ...    a57081108
# 3                            [問題] 停車費回饋排除  ...       du3045
# 4                       [新聞] 振興三倍券選臺灣企銀就對  ...   hvariables
# 5                       [心得] 渣打現金回饋御璽卡 核卡  ...        h0304
# 6                    [問題] 非訂房網的飯店住宿回饋的信用卡  ...         sbas
# 7                        [問題] 請問信用卡代扣款電信費  ...      ludashi
# 8                       [心得] 渣打現金回饋御璽卡 未過  ...   swingangel
# 9         [心得] 星展 炫晶御璽/台新 @gogo icash MIT  ...     basterds
# 10                      [心得] 渣打現金回饋御璽卡 核卡  ...    Aruto1121
# 11                [心得] 富邦J卡、聯邦賴點卡、永豐幣倍卡核卡  ...         ldiv
# 12                          [心得]  滙豐旅人卡核卡  ...     BankSide
# 13                           [問題] 水電費扣繳問題  ...       sumade
# 14       [討論] 台灣Pay 新光銀行加碼4% 每月只有5萬元預算...  ...   bookticket
# 15                   [心得] 新光寰宇 新光三越 JCB未核  ...     God03855
# 16                         [問題] 渣打的他網辦卡連結  ...      ohmywei
# 17  [公告] === 卡板板規 V8.0 === (2018/05/25修訂)  ...  MoonAthenaX
# 18                            [公告] 置底檢舉專區  ...     bboy0720
# 19                     [情報] 各家銀行0800免付費電話  ...  MoonAthenaX
# 20       [整理] 2020下 小資族 日常消費 回饋統整 (06/30)  ...   DarkRobert
# 21               [心得] 2020下半年用卡整理 (7/5更新)  ...      cokelon
# 22                      [心得] 渣打現金回饋御璽卡 核卡  ...    bugerbite
# 23                      [問題] 永豐幣倍卡實際刷卡金額？  ...  sunsky13579
# 24                     [心得] 渣打現金回饋御璽卡  核卡  ...    a57081108
# 25                           [問題] 停車費回饋排除  ...       du3045
# 26                      [新聞] 振興三倍券選臺灣企銀就對  ...   hvariables
# 27                      [心得] 渣打現金回饋御璽卡 核卡  ...        h0304
# 28                   [問題] 非訂房網的飯店住宿回饋的信用卡  ...         sbas
# 29                       [問題] 請問信用卡代扣款電信費  ...      ludashi
# 30                      [心得] 渣打現金回饋御璽卡 未過  ...   swingangel
# 31        [心得] 星展 炫晶御璽/台新 @gogo icash MIT  ...     basterds
# 32                      [心得] 渣打現金回饋御璽卡 核卡  ...    Aruto1121
# 33                [心得] 富邦J卡、聯邦賴點卡、永豐幣倍卡核卡  ...         ldiv
# 34                          [心得]  滙豐旅人卡核卡  ...     BankSide
# 35                           [問題] 水電費扣繳問題  ...       sumade
# 36       [討論] 台灣Pay 新光銀行加碼4% 每月只有5萬元預算...  ...   bookticket
# 37                   [心得] 新光寰宇 新光三越 JCB未核  ...     God03855
# 38                         [問題] 渣打的他網辦卡連結  ...      ohmywei
# 39  [公告] === 卡板板規 V8.0 === (2018/05/25修訂)  ...  MoonAthenaX
# 40                            [公告] 置底檢舉專區  ...     bboy0720
# 41                     [情報] 各家銀行0800免付費電話  ...  MoonAthenaX
# 42       [整理] 2020下 小資族 日常消費 回饋統整 (06/30)  ...   DarkRobert
# 43               [心得] 2020下半年用卡整理 (7/5更新)  ...      cokelon
#
# [44 rows x 4 columns]
